# %% [markdown]
# ### Домашнее задание 4
# ### Даны два списка.
# Дата покупки
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
#
#
# Суммы покупок по датам
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#
# Найдите, какая выручка у компании в ноябре
# Используйте list comprehensions

# %%
data_p = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']

# %%
sum_p = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

# %%
renevue_november = sum([sum for data1, sum in zip(data_p, sum_p) if data1.split('-')[1] == '11'])
print("Выручка компании в ноябре:", renevue_november)
# Out:
# Выручка компании в ноябре: 25098

# %% [markdown]
# Найдите выручку компании в зависимости от месяца
# Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.

# %%
def выручка_по_месяцам(даты: list[str], суммы_покупок: list[int]) -> dict[str, int]:
    выручка_по_месяцам = {}
    for дата, сумма in zip(data_p, sum_p):
        месяц = дата.split('-')[1]
        if месяц in выручка_по_месяцам:
            выручка_по_месяцам[месяц] += сумма
        else:
            выручка_по_месяцам[месяц] = сумма
    return выручка_по_месяцам

выручка_по_месяцам = выручка_по_месяцам(даты, суммы_покупок)
print("Выручка компании по месяцам:", выручка_по_месяцам)
# Out:
# Выручка компании по месяцам: {'09': 25647, '12': 45452, '10': 28645, '11': 25098}
